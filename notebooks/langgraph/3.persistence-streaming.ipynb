# %% [markdown]
# # Lesson 4: Persistence and Streaming

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=2)

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in sf?")]

# %%
thread = {"configurable": {"thread_id": "1"}}

# %%
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v['messages'])
# Out:
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 151, 'total_tokens': 173, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6a1058d4-b057-4c05-be29-ec9b975be884-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}])]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}
# Back to the model!
# [ToolMessage(content="HTTPError('500 Server Error: Internal Server Error for url: http://jupyter-api-proxy.internal.dlai/rev-proxy/tavily_search/search')", name='tavily_search_results_json', tool_call_id='call_bmfLa92f6oAIKN9KvXtqbKDz')]
# [AIMessage(content='I encountered an error while trying to retrieve the current weather in San Francisco. You might want to check a weather website or app like Weather.com or the Weather Channel for the most accurate and up-to-date information. If you have another query or need further assistance, feel free to ask!', response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 218, 'total_tokens': 276, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_ed643dde95', 'finish_reason': 'stop', 'logprobs': None}, id='run-1757773e-fecb-4737-94cb-a7f5a5d6353b-0')]

# %%
messages = [HumanMessage(content="What about in la?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_EvJvGDgTHkdY2T64ijcqKQ32', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 288, 'total_tokens': 310, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_689bad8e9a', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-65e615e3-ca53-434a-b74d-fe5d72741188-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_EvJvGDgTHkdY2T64ijcqKQ32'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_EvJvGDgTHkdY2T64ijcqKQ32'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/june-weather/347625\', \'content\': "June Weather in Los Angeles. Los Angeles\'s June 2026 forecast shows daily high temperatures ranging from 74° to 80°, with overnight lows between 60° and 62°."}, {\'url\': \'https://www.weather2travel.com/california/los-angeles/june\', \'content\': "weather2travel.com - travel deals for your holiday in the sun\\nClick to search\\n\\n# Los Angeles weather in June 2026\\n\\nExpect  daytime maximum temperatures of 26°C in Los Angeles, California in June based on long-term weather averages. There are 10 hours of sunshine per day on average.\\n\\n26°C maximum daytime temperature in June in Los Angeles\\n10 hours of sunshine per day (67% of daylight hours) in June in Los Angeles\\n0 days with some rainfall in June in Los Angeles\\n15°C minimum night-time temperature in June in Los Angeles\\n14 hours of daylight per day in June in Los Angeles\\nLow heat & humidity in June in Los Angeles\\n1 mm monthly rainfall in June in Los Angeles\\nUV (maximum) index 10 (Very High) in June in Los Angeles\\n\\n### More about Los Angeles [...] ### Does it ever rain in Los Angeles in June?\\n\\nThere are usually no days with some rain in Los Angeles in June and the average monthly rainfall is 1mm.\\n\\n## Los Angeles June sunrise & sunset times\\n\\nBrowse the sunrise and sunset times for Los Angeles in June 2026. Select a month to view Los Angeles sunrise and sunset times for the next 12 months.\\n\\nJanFebMarAprMayJunJulAugSepOctNovDec\\n\\n| Date | Sunrise times | Sunset times |\\n --- \\n| Monday, 1st June 2026 | 04:43 | 18:59 |\\n| Monday, 15th June 2026 | 04:41 | 19:06 |\\n| Tuesday, 30th June 2026 | 04:45 | 19:08 |\\n\\n## Be inspired\\n\\nGet your weekly fix of holiday inspiration from some of the world\'s best travel writers plus save on your next trip with the latest exclusive offers\\n\\nWe promise not to share your details\\n\\n## Related posts [...] The June weather guide for California (Los Angeles) shows long term weather averages processed from data supplied by CRU (University of East Anglia), the Met Office & the Netherlands Meteorological Institute. Find out more about our data sources.\\n\\n### More about Los Angeles\\n\\nA sports lover\'s guide to Los Angeles\\nHow to explore LA on a budget\\nLos Angeles for beginners\\n\\n### How hot is it in Los Angeles in June?\\n\\nDaytime temperatures usually reach 26°C in Los Angeles in June with low heat and humidity, falling to 15°C at night.\\n\\n### How sunny is it in Los Angeles in June?\\n\\nThere are normally 10 hours of bright sunshine each day in Los Angeles in June - that\'s 67% of daylight hours.\\n\\n### Does it ever rain in Los Angeles in June?"}]', name='tavily_search_results_json', tool_call_id='call_EvJvGDgTHkdY2T64ijcqKQ32')]}
# {'messages': [AIMessage(content="I couldn't find the current weather in Los Angeles, but I can provide some general information about the weather in Los Angeles in June. During June, Los Angeles typically experiences daytime temperatures ranging from 74°F to 80°F (approximately 23°C to 27°C) with overnight lows between 60°F and 62°F (around 15°C to 17°C). There are usually around 10 hours of sunshine per day, and rainfall is rare.\n\nFor the most accurate and up-to-date weather information, I recommend checking a reliable weather source like Weather.com or using a weather app on your device. If you have any other questions, feel free to ask!", response_metadata={'token_usage': {'completion_tokens': 135, 'prompt_tokens': 990, 'total_tokens': 1125, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'stop', 'logprobs': None}, id='run-bd1e2615-a706-44e6-a1c0-143132425064-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Ims4CbAeGAfoKg6sBhw9R2uC', 'function': {'arguments': '{"query": "current temperature in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}, {'id': 'call_dnCktolTiPeifSO4I905i2EU', 'function': {'arguments': '{"query": "current temperature in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1137, 'total_tokens': 1197, 'prompt_tokens_details': {'cached_tokens': 1024, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-6967dbe7-f85a-4f80-88b6-c98e46a3062e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in San Francisco'}, 'id': 'call_Ims4CbAeGAfoKg6sBhw9R2uC'}, {'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in Los Angeles'}, 'id': 'call_dnCktolTiPeifSO4I905i2EU'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in San Francisco'}, 'id': 'call_Ims4CbAeGAfoKg6sBhw9R2uC'}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current temperature in Los Angeles'}, 'id': 'call_dnCktolTiPeifSO4I905i2EU'}
# Back to the model!
# {'messages': [ToolMessage(content="HTTPError('500 Server Error: Internal Server Error for url: http://jupyter-api-proxy.internal.dlai/rev-proxy/tavily_search/search')", name='tavily_search_results_json', tool_call_id='call_Ims4CbAeGAfoKg6sBhw9R2uC'), ToolMessage(content='[{\'url\': \'https://weather.com/us/california/city/los-angeles/today\', \'content\': "Forecasts\\n\\nRadar\\n\\nExplore\\n\\nMore\\n\\nSign in\\n\\nFeels Like\\n\\n--\\n\\nHHigh\\n\\n--\\n\\nLLow\\n\\n--\\n\\nChance of Rain\\n\\n0%\\n\\n## Today\'s Outlook\\n\\n# Daily Forecast\\n\\n## Trending Now\\n\\n## Heat domes are bad news for your body\\n\\n1:19\\n\\n## Sahara Desert dust is coming to US\\n\\n## NHC eyes Atlantic for tropical development\\n\\n1:15\\n\\n## Fourth of July firework forecast\\n\\n## Heat domes are bad news for your body\\n\\n1:19\\n\\n## Sahara Desert dust is coming to US\\n\\n## NHC eyes Atlantic for tropical development\\n\\n1:15\\n\\n## Fourth of July firework forecast\\n\\n## Editor\'s Pick\\n\\n## Too hot for takeoff: Why heat can ground your plane\\n\\nWhen you think of weather-induced airport delays, heat is probably not the first thing to come to mind. But here’s why it\'s just as dangerous.\\n\\nThe Weather Company\\nThe Weather Channel\\nWeather Underground\\nStorm Radar [...] The Weather Channel is the world\'s most accurate forecaster according to ForecastWatch, Global and Regional Weather Forecast Accuracy Overview, 2021-2024, commissioned by The Weather Company.\\n\\nWeather Channel.\\n\\nPrivacy & Legal\\n\\nTerms of Use\\n\\nPrivacy Policy\\n\\nData Rights\\n\\nPrivacy Settings\\n\\nCookie Notice\\n\\nData Vendors\\n\\nAdChoices\\n\\nAccessibility Statement\\n\\nFooter.communityGuidelines\\n\\nMore\\n\\nMission\\n\\nNewsletter Sign Up\\n\\nFeedback\\n\\nCareers\\n\\nNews Room\\n\\nAdvertise With Us\\n\\nTV\\n\\nWeather Data APIs\\n\\nAlexa Skill\\n\\nWeather Labs\\n\\nFooter.atmosphere\\n\\nSitemap\\n\\n© The Weather Company, LLC 2026\\n\\nExplore Georgia\\nEssential Accessibility"}, {\'url\': \'https://www.weather.gov/lox\', \'content\': \'National Weather Service\\nUnited States Department of Commerce\\n\\nNWS\\n\\nAll NOAA\\n\\nPrivacy Policy\\n\\nLos Angeles, CA\\n\\nWeather Forecast Office\\n\\n# NWS Forecast Office Los Angeles, CA\\n\\nLast Map Update:\\nTue, Jun 30, 2026 at 11:18:33 am PDT\\n\\nNational Weather Service San Francisco Bay Area, CA\\nNational Weather Service San Joaquin Valley, CA\\nNational Weather Service Las Vegas, NV\\nNational Weather Service Honolulu, HI\\nNational Weather Service NWS Phoenix\\nNational Weather Service Honolulu, HI\\nNational Weather Service San Diego, CA\\nNational Weather Service San Diego, CA\\n\\n|  |\\n\\n| Text Product Selector (Selected product opens in current window) |\\n| Latest Text Products Issued | | [...] Hazards\\nObservations\\nMarine Weather\\nFire Weather\\nAviation\\nHydrology\\nForecast Discussion\\nGraphical Forecasts\\nFast Page\\nA chart of weather statics\\nMobile\\nFind Past Weather Data\\nSouthern CA Radar\\nSouthwest CA Radar\\nSatellite\\nSocial Media OneStop\\nStudent Opportunities\\nFollow us on X\\nFollow us on Facebook\\nFollow us on YouTube\\nLOX RSS Feed\\nusa.gov\\n\\nUS Dept of Commerce  \\nNational Oceanic and Atmospheric Administration  \\nNational Weather Service  \\nLos Angeles, CA  \\n 520 North Elevar Street  \\nOxnard, CA 93030\\n  \\n805-988-6610  \\n  \\nComments? Questions? Please Contact Us.\'}]', name='tavily_search_results_json', tool_call_id='call_dnCktolTiPeifSO4I905i2EU')]}
# {'messages': [AIMessage(content="I encountered an error retrieving the current temperature in San Francisco, but I was able to access some sources for Los Angeles. Unfortunately, I couldn't extract specific temperature data for Los Angeles from those sources either.\n\nFor accurate and current temperature comparisons, I recommend checking a reliable weather website or app like Weather.com for both San Francisco and Los Angeles. If you have any more questions or need further help, feel free to ask!", response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 2166, 'total_tokens': 2250, 'prompt_tokens_details': {'cached_tokens': 1152, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'stop', 'logprobs': None}, id='run-b39da21c-3e75-4079-a12e-ac428e0da39f-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Could you please clarify what you're comparing to determine which is warmer? Are you comparing two specific locations, types of clothing, materials, or something else? Let me know so I can provide the appropriate information.", response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 149, 'total_tokens': 192, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-19b86dd8-0988-4ad7-9bc8-6f3c1e0c6ecd-0')]}

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.aiosqlite import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}
async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_GiHnpbt7P6kuX4g2n6imqDXI'}
# /usr/local/lib/python3.11/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: This API is in beta and may change in the future.
#   warn_beta(
# Back to the model!
# The| current| weather| in| San| Francisco| is| mostly| sunny| with| a| high| of| |66|°F| and| a| low| of| |54|°F|.| Winds| are| coming| from| the| W|SW| at| |10| to| |20| mph|.|
